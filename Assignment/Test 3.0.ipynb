# %% [markdown]
# Task 1

# %%
import pandas as pd
import numpy as np
from numpy.random import randint as ri
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {
 'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
 'Age': [24, 27, 22, 32, 29],
 'Score': [85.5, 90.3, 88.0, 92.1, 78.8]
}
df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#              Age      Score
# count   5.000000   5.000000
# mean   26.800000  86.940000
# std     3.962323   5.181023
# min    22.000000  78.800000
# 25%    24.000000  85.500000
# 50%    27.000000  88.000000
# 75%    29.000000  90.300000
# max    32.000000  92.100000

# %%
df.head()
# Out:
#       Name  Age  Score
# 0    Alice   24   85.5
# 1      Bob   27   90.3
# 2  Charlie   22   88.0
# 3    David   32   92.1
# 4      Eve   29   78.8

# %%
df[['Name', 'Score']]
# Out:
#       Name  Score
# 0    Alice   85.5
# 1      Bob   90.3
# 2  Charlie   88.0
# 3    David   92.1
# 4      Eve   78.8

# %%
df[df['Age'] > 25]
# Out:
#     Name  Age  Score
# 1    Bob   27   90.3
# 3  David   32   92.1
# 4    Eve   29   78.8

# %%
df['Passed'] = df['Score'] > 80
df
# Out:
#       Name  Age  Score  Passed
# 0    Alice   24   85.5    True
# 1      Bob   27   90.3    True
# 2  Charlie   22   88.0    True
# 3    David   32   92.1    True
# 4      Eve   29   78.8   False

# %%
sorting = df.sort_values(by='Score', ascending=False)
sorting
# Out:
#       Name  Age  Score  Passed
# 3    David   32   92.1    True
# 1      Bob   27   90.3    True
# 2  Charlie   22   88.0    True
# 0    Alice   24   85.5    True
# 4      Eve   29   78.8   False

# %%
mean = df.groupby('Passed')['Score'].mean()
mean
# Out:
# Passed
# False    78.800
# True     88.975
# Name: Score, dtype: float64

# %%
df['Attendance'] = [90, np.nan, 85, 87, np.nan]
df['Attendance'].fillna(df['Attendance'].mean(), inplace=True)
df
# Out:
# C:\Users\mdzai\AppData\Local\Temp\ipykernel_19508\73865874.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].fillna(df['Attendance'].mean(), inplace=True)
#       Name  Age  Score  Passed  Attendance
# 0    Alice   24   85.5    True   90.000000
# 1      Bob   27   90.3    True   87.333333
# 2  Charlie   22   88.0    True   85.000000
# 3    David   32   92.1    True   87.000000
# 4      Eve   29   78.8   False   87.333333

# %%
a = np.arange(10,19)
a
# Out:
# array([10, 11, 12, 13, 14, 15, 16, 17, 18])

# %%
a=ri(10,19,30)
print(a)
# Out:
# [16 17 10 14 12 18 17 12 14 14 14 14 17 12 17 10 17 11 15 17 18 14 18 14
#  15 16 10 13 17 11]

# %%
x = a.reshape(1,2,5)
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 x = a.reshape(1,2,5)
#       2 print(x)
#
# ValueError: cannot reshape array of size 30 into shape (1,2,5)

# %%
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])
y = array1 + array2
y
# Out:
# array([5, 7, 9])

# %%
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])
z = array1 * array2
z
# Out:
# array([ 4, 10, 18])

# %%
array = np.array([10, 20, 30, 40, 50])
s = array[[1, 3]]
s
# Out:
# array([20, 40])

# %%
array = np.array([1, 2, 3, 4, 5, 6])
d = array[1:4]
d
# Out:
# array([2, 3, 4])

# %%
array = np.array([10, 20, 30, 40, 50])
mean = np.mean(array)
print(mean)
standard = np.std(array)
print(standard)
# Out:
# 30.0
# 14.142135623730951

# %%
print(np.eye(3))
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
data = [12, 15, 14, 10, 8, 11, 14, 18, 22, 24, 30, 28, 26, 30, 32, 35, 38]
df = pd.DataFrame(data)

plt.show()

# %%
plt.hist(data)
# Out:
# (array([2., 2., 3., 1., 1., 1., 2., 2., 1., 2.]),
#  array([ 8., 11., 14., 17., 20., 23., 26., 29., 32., 35., 38.]),
#  <BarContainer object of 10 artists>)

# %%
data = {
    'Individual': ['A', 'B', 'C', 'D', 'E'],
    'Score': [85, 90, 78, 92, 88]
}
df = pd.DataFrame(data)
sns.barplot(x='Individual', y='Score', data=df, palette='viridis')
plt.show()
# Out:
# C:\Users\mdzai\AppData\Local\Temp\ipykernel_22600\804795049.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Individual', y='Score', data=df, palette='viridis')

# %%
labels = ['Apples', 'Bananas', 'Cherries', 'Dates']
sizes = [10, 15, 7, 3]
plt.pie(sizes, labels=labels)
plt.show()
